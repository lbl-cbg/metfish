# %%
import mdtraj as md
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
output_path='/global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles'
ref_path='/global/cfs/cdirs/m4704/100125_Nature_Com_data/Apo_holo_data/pdbs'

# %%
def extract_ensemble(output_path, pdb_id):
    loss_csv=os.path.join(output_path, pdb_id, 'saved_structures.csv')
    loss_pd=pd.read_csv(loss_csv)
    loss_pd=loss_pd[~loss_pd['full_path'].str.contains('best')]
    loss_pd=loss_pd.sort_values(by='loss').reset_index(drop=True).head(50)
    return loss_pd

# %%
df=extract_ensemble(output_path,'1AEL-12_A')

# %%
def calc_Heli(t,length):
    dssp = md.compute_dssp(t)
    dssp_count = np.zeros((1, length))
    for j in range(t.n_residues):
            if dssp[0,j] in 'H':
                dssp_count[0,j] += 1
    summary = dssp_count.sum(axis=1)
    return(summary[0]/length)

def calc_Beta(t,length):
    dssp = md.compute_dssp(t)
    dssp_count = np.zeros((1, t.n_residues))
    for j in range(t.n_residues):
        if dssp[0,j] in 'E':
            dssp_count[0,j] += 1
    summary = dssp_count.sum(axis=1)
    return(summary[0]/length)

def calc_Rg(t):
    d = md.compute_rg(t)
    return(d[0])
    
def calc_Re(t):
    topology=t.topology
    rpology=topology.select_atom_indices(selection='alpha')
    d = md.compute_distances(t,[[rpology[0],rpology[-1]]])
    return(d[0][0])

# %%
def calc_contact(t):
    contact=md.compute_contacts(t, contacts='all', scheme='ca')
    # Use distance or the contact?
    contact_square=md.geometry.squareform(contact[0]<0.8,contact[1])
    #contact_square=md.geometry.squareform(contact[0],contact[1])
    return contact_square[0]

# %%
def analyze_conformation(confor_path):
    result_dic={}
    confor_frame = md.load(confor_path)
    length = confor_frame.n_residues
    confor_rg = calc_Rg(confor_frame)
    confor_re = calc_Re(confor_frame)
    confor_helicity =  calc_Heli(confor_frame,length)
    confor_beta = calc_Beta(confor_frame,length)
    confor_contact = calc_contact(confor_frame)
    result_dict={'seq_length':length,
                'rg':confor_rg,
                're':confor_re,
                'helicity':confor_helicity,
                'beta':confor_beta,}
    return result_dict, confor_contact, confor_frame

# %%
#df.loc[0,'full_path']

# %%
#analyze_conformation(df.loc[0,'full_path'])

# %%
def generate_rmsd_alphaSAXS(pdb_id,ref_path,output_path):
    results=[]
    contact_maps=[]
    ref_result, ref_contact, ref_t = analyze_conformation(os.path.join(ref_path,pdb_id+'.pdb'))
    ref_atom=ref_t.topology.select('name CA')
    generated_pdb_df = extract_ensemble(output_path,pdb_id)
    for index, single_pdb in generated_pdb_df.iterrows():
        saxs_loss = single_pdb['loss']
        result_dict, confor_contact, confor_frame = analyze_conformation(single_pdb['full_path'])
        contact_maps.append(confor_contact)
        confor_atom=confor_frame.topology.select('name CA')
        if len(confor_atom)!=len(ref_atom):
            print(pdb_id+' has the wrong length')
            print(test_frame, len(test_atom), ref_t, len(ref_atom))
            continue
        ca_rmsd=md.rmsd(confor_frame,ref_t,0,confor_atom,ref_atom)
        result_dict['rmsd']=ca_rmsd[0]*10
        result_dict['loss']=saxs_loss
        results.append(result_dict)
    averages = {
    key: np.mean([r[key] for r in results])
    for key in results[0].keys()
}
    best = min(results, key=lambda d: d['rmsd'])
    return averages,ref_result, contact_maps,ref_contact,results,best

# %%
averages,ref_result, contact_maps,ref_contact,results, best= generate_rmsd_alphaSAXS('2RS9-13_B',ref_path,output_path)

# %%
averages
# Out:
# {'seq_length': 121.0,
#  'rg': 1.562715363690142,
#  're': 2.2861478,
#  'helicity': 0.6231404958677687,
#  'beta': 0.0,
#  'rmsd': 3.3605404675006865,
#  'loss': 0.033646567200000005}

# %%
ref_result
# Out:
# {'seq_length': 121,
#  'rg': 1.592974442925032,
#  're': 4.033096,
#  'helicity': 0.628099173553719,
#  'beta': 0.0}

# %%
pdb_list=[ f[:-4] for f in os.listdir(ref_path) if f.endswith('.pdb')]

# %%
def build_protein_row(protein_id, averages, ref_result, best):
    metrics = ['seq_length', 'rg', 're', 'helicity', 'beta', 'rmsd','loss']
    row = {'protein_id': protein_id}
    for m in metrics:
        row[f'{m}_avg'] = averages.get(m, None)
        row[f'{m}_ref'] = ref_result.get(m, None)
        row[f'{m}_best'] = best.get(m, None)
    return row

# %%
rows=[]
results_dict={}
contact_dict={}
contact_ref={}
for i in pdb_list:
    try:
        averages,ref_result, contact_maps,ref_contact,results, best=generate_rmsd_alphaSAXS(i,ref_path,output_path)
        row = build_protein_row(i, averages, ref_result, best)
        results_dict[i]= results
        contact_dict[i]= contact_maps
        contact_ref[i]=ref_result
        rows.append(row) 
    except:
        print(f'{i} is not in the prediction dataset')

# %%
rows
# Out:
# [{'protein_id': '2K8R-1_A',
#   'seq_length_avg': 133.0,
#   'seq_length_ref': 133,
#   'seq_length_best': 133,
#   'rg_avg': 1.3737933046632111,
#   'rg_ref': 1.3777686676285295,
#   'rg_best': 1.3695647490598248,
#   're_avg': 1.5367163,
#   're_ref': 0.8620291,
#   're_best': 1.4137695,
#   'helicity_avg': 0.08375939849624058,
#   'helicity_ref': 0.09022556390977443,
#   'helicity_best': 0.09022556390977443,
#   'beta_avg': 0.39609022556390977,
#   'beta_ref': 0.3007518796992481,
#   'beta_best': 0.40601503759398494,
#   'rmsd_avg': 3.7132869362831116,
#   'rmsd_ref': None,
#   'rmsd_best': 3.5803166031837463,
#   'loss_avg': 0.0151171524,
#   'loss_ref': None,
#   'loss_best': 0.01371296},
#  {'protein_id': '1XSA-23_A',
#   'seq_length_avg': 153.0,
#   'seq_length_ref': 153,
#   'seq_length_best': 153,
#   'rg_avg': 1.4823223659034523,
#   'rg_ref': 1.4687494692987917,
#   'rg_best': 1.4873055794681653,
#   're_avg': 4.640028,
#   're_ref': 4.452528,
#   're_best': 5.152053,
#   'helicity_avg': 0.06549019607843137,
#   'helicity_ref': 0.26143790849673204,
#   'helicity_best': 0.058823529411764705,
#   'beta_avg': 0.3420915032679738,
#   'beta_ref': 0.3006535947712418,
#   'beta_best': 0.35947712418300654,
#   'rmsd_avg': 3.553883397579193,
#   'rmsd_ref': None,
#   'rmsd_best': 3.0253198742866516,
#   'loss_avg': 0.0295113048,
#   'loss_ref': None,
#   'loss_best': 0.03187927},
#  {'protein_id': '1K2H-4_A',
#   'seq_length_avg': 93.0,
#   'seq_length_ref': 93,
#   'seq_length_best': 93,
#   'rg_avg': 1.4031403944728138,
#   'rg_ref': 1.40354525067569,
#   'rg_best': 1.3913609995218745,
#   're_avg': 3.8093019,
#   're_ref': 3.23232,
#   're_best': 3.8122022,
#   'helicity_avg': 0.6090322580645161,
#   'helicity_ref': 0.6451612903225806,
#   'helicity_best': 0.5806451612903226,
#   'beta_avg': 0.045161290322580656,
#   'beta_ref': 0.043010752688172046,
#   'beta_best': 0.043010752688172046,
#   'rmsd_avg': 6.449603497982025,
#   'rmsd_ref': None,
#   'rmsd_best': 5.955379605293274,
#   'loss_avg': 0.0703894682,
#   'loss_ref': None,
#   'loss_best': 0.07182862},
#  {'protein_id': '2D9E-12_A',
#   'seq_length_avg': 121.0,
#   'seq_length_ref': 121,
#   'seq_length_best': 121,
#   'rg_avg': 1.5269641774460616,
#   'rg_ref': 1.5187304255852954,
#   'rg_best': 1.5195892697521982,
#   're_avg': 2.109292,
#   're_ref': 2.1778164,
#   're_best': 1.7444081,
#   'helicity_avg': 0.5682644628099174,
#   'helicity_ref': 0.6115702479338843,
#   'helicity_best': 0.6198347107438017,
#   'beta_avg': 0.0004958677685950413,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 3.4457594752311707,
#   'rmsd_ref': None,
#   'rmsd_best': 2.6765677332878113,
#   'loss_avg': 0.019319163,
#   'loss_ref': None,
#   'loss_best': 0.01984841},
#  {'protein_id': '1P7M-18_A',
#   'seq_length_avg': 187.0,
#   'seq_length_ref': 187,
#   'seq_length_best': 187,
#   'rg_avg': 1.7057116055557164,
#   'rg_ref': 1.7121877777672578,
#   'rg_best': 1.702929847336192,
#   're_avg': 1.3588455,
#   're_ref': 2.1191704,
#   're_best': 1.4257221,
#   'helicity_avg': 0.5674866310160429,
#   'helicity_ref': 0.5401069518716578,
#   'helicity_best': 0.5561497326203209,
#   'beta_avg': 0.028235294117647056,
#   'beta_ref': 0.0213903743315508,
#   'beta_best': 0.0213903743315508,
#   'rmsd_avg': 2.406974333524704,
#   'rmsd_ref': None,
#   'rmsd_best': 2.256147563457489,
#   'loss_avg': 0.0152447302,
#   'loss_ref': None,
#   'loss_best': 0.01637184},
#  {'protein_id': '1EX6_B',
#   'seq_length_avg': 186.0,
#   'seq_length_ref': 393,
#   'seq_length_best': 186,
#   'rg_avg': 1.7129811790848881,
#   'rg_ref': 1.832680997054291,
#   'rg_best': 1.7035966995231409,
#   're_avg': 1.1094795,
#   're_ref': 0.88316137,
#   're_best': 0.9560477,
#   'helicity_avg': 0.43172043010752686,
#   'helicity_ref': 0.1984732824427481,
#   'helicity_best': 0.43548387096774194,
#   'beta_avg': 0.22989247311827954,
#   'beta_ref': 0.10178117048346055,
#   'beta_best': 0.23118279569892472,
#   'rmsd_avg': 3.0408418476581573,
#   'rmsd_ref': None,
#   'rmsd_best': 2.664045989513397,
#   'loss_avg': 0.08498016799999998,
#   'loss_ref': None,
#   'loss_best': 0.08809476},
#  {'protein_id': '2AI6-18_A',
#   'seq_length_avg': 125.0,
#   'seq_length_ref': 125,
#   'seq_length_best': 125,
#   'rg_avg': 1.4488336605042285,
#   'rg_ref': 1.4557362959046223,
#   'rg_best': 1.4390658426443477,
#   're_avg': 4.275695,
#   're_ref': 4.709083,
#   're_best': 4.3078356,
#   'helicity_avg': 0.08272,
#   'helicity_ref': 0.232,
#   'helicity_best': 0.112,
#   'beta_avg': 0.33088,
#   'beta_ref': 0.352,
#   'beta_best': 0.32,
#   'rmsd_avg': 3.1805304527282714,
#   'rmsd_ref': None,
#   'rmsd_best': 2.9023537039756775,
#   'loss_avg': 0.027004426399999993,
#   'loss_ref': None,
#   'loss_best': 0.02687395},
#  {'protein_id': '1MO8-14_A',
#   'seq_length_avg': 213.0,
#   'seq_length_ref': 213,
#   'seq_length_best': 213,
#   'rg_avg': 1.724184670731563,
#   'rg_ref': 1.725500820947981,
#   'rg_best': 1.8025682359368724,
#   're_avg': 1.9600323,
#   're_ref': 0.5266304,
#   're_best': 1.1505905,
#   'helicity_avg': 0.07323943661971831,
#   'helicity_ref': 0.215962441314554,
#   'helicity_best': 0.06103286384976526,
#   'beta_avg': 0.15136150234741783,
#   'beta_ref': 0.1267605633802817,
#   'beta_best': 0.15492957746478872,
#   'rmsd_avg': 17.484772324562073,
#   'rmsd_ref': None,
#   'rmsd_best': 15.44576644897461,
#   'loss_avg': 0.14770346099999998,
#   'loss_ref': None,
#   'loss_best': 0.14697963},
#  {'protein_id': '2KXL-8_A',
#   'seq_length_avg': 142.0,
#   'seq_length_ref': 142,
#   'seq_length_best': 142,
#   'rg_avg': 1.5107265787593476,
#   'rg_ref': 1.5091980982824023,
#   'rg_best': 1.5061258484142679,
#   're_avg': 5.341499,
#   're_ref': 4.634607,
#   're_best': 5.2602053,
#   'helicity_avg': 0.39028169014084513,
#   'helicity_ref': 0.38028169014084506,
#   'helicity_best': 0.4014084507042254,
#   'beta_avg': 0.2554929577464789,
#   'beta_ref': 0.24647887323943662,
#   'beta_best': 0.2535211267605634,
#   'rmsd_avg': 3.7711502850055694,
#   'rmsd_ref': None,
#   'rmsd_best': 3.4558069705963135,
#   'loss_avg': 0.018808205,
#   'loss_ref': None,
#   'loss_best': 0.01901604},
#  {'protein_id': '1TJD_A',
#   'seq_length_avg': 216.0,
#   'seq_length_ref': 216,
#   'seq_length_best': 216,
#   'rg_avg': 1.8985413714919313,
#   'rg_ref': 1.8654663820494666,
#   'rg_best': 1.8913902701676844,
#   're_avg': 4.010394,
#   're_ref': 4.4086027,
#   're_best': 4.09464,
#   'helicity_avg': 0.357962962962963,
#   'helicity_ref': 0.3888888888888889,
#   'helicity_best': 0.32407407407407407,
#   'beta_avg': 0.2087037037037037,
#   'beta_ref': 0.20833333333333334,
#   'beta_best': 0.2037037037037037,
#   'rmsd_avg': 3.140790808200836,
#   'rmsd_ref': None,
#   'rmsd_best': 2.675509452819824,
#   'loss_avg': 0.037089505,
#   'loss_ref': None,
#   'loss_best': 0.03428155},
#  {'protein_id': '2VCD-8_A',
#   'seq_length_avg': 137.0,
#   'seq_length_ref': 137,
#   'seq_length_best': 137,
#   'rg_avg': 1.4754697017146128,
#   'rg_ref': 1.4879620024600242,
#   'rg_best': 1.4803655739866715,
#   're_avg': 5.043843,
#   're_ref': 4.4950037,
#   're_best': 4.9198904,
#   'helicity_avg': 0.1731386861313869,
#   'helicity_ref': 0.23357664233576642,
#   'helicity_best': 0.145985401459854,
#   'beta_avg': 0.3205839416058394,
#   'beta_ref': 0.30656934306569344,
#   'beta_best': 0.32116788321167883,
#   'rmsd_avg': 2.112714669108391,
#   'rmsd_ref': None,
#   'rmsd_best': 1.7165842652320862,
#   'loss_avg': 0.0256359508,
#   'loss_ref': None,
#   'loss_best': 0.02541574},
#  {'protein_id': '2F63-4_A',
#   'seq_length_avg': 158.0,
#   'seq_length_ref': 158,
#   'seq_length_best': 158,
#   'rg_avg': 1.4655454939327888,
#   'rg_ref': 1.4432170291021464,
#   'rg_best': 1.4557602583517313,
#   're_avg': 2.787479,
#   're_ref': 2.9291146,
#   're_best': 2.7804403,
#   'helicity_avg': 0.2982278481012658,
#   'helicity_ref': 0.2721518987341772,
#   'helicity_best': 0.310126582278481,
#   'beta_avg': 0.2750632911392405,
#   'beta_ref': 0.14556962025316456,
#   'beta_best': 0.2721518987341772,
#   'rmsd_avg': 2.753016692399979,
#   'rmsd_ref': None,
#   'rmsd_best': 2.3680096864700317,
#   'loss_avg': 0.0420969066,
#   'loss_ref': None,
#   'loss_best': 0.03344042},
#  {'protein_id': '1ROE-10_A',
#   'seq_length_avg': 97.0,
#   'seq_length_ref': 97,
#   'seq_length_best': 97,
#   'rg_avg': 1.205637433605152,
#   'rg_ref': 1.2026723882169725,
#   'rg_best': 1.2033191112050232,
#   're_avg': 3.577571,
#   're_ref': 3.051452,
#   're_best': 3.5833871,
#   'helicity_avg': 0.2002061855670103,
#   'helicity_ref': 0.09278350515463918,
#   'helicity_best': 0.21649484536082475,
#   'beta_avg': 0.32123711340206185,
#   'beta_ref': 0.16494845360824742,
#   'beta_best': 0.29896907216494845,
#   'rmsd_avg': 4.381982910633087,
#   'rmsd_ref': None,
#   'rmsd_best': 4.202966392040253,
#   'loss_avg': 0.033566694,
#   'loss_ref': None,
#   'loss_best': 0.03442128},
#  {'protein_id': '1CZ2-8_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.2270771656014652,
#   'rg_ref': 1.2273715139201573,
#   'rg_best': 1.2263185583726424,
#   're_avg': 1.4869248,
#   're_ref': 1.3755581,
#   're_best': 1.4476312,
#   'helicity_avg': 0.6186666666666667,
#   'helicity_ref': 0.5666666666666667,
#   'helicity_best': 0.6111111111111112,
#   'beta_avg': 0.0,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 2.442490500211716,
#   'rmsd_ref': None,
#   'rmsd_best': 2.270028293132782,
#   'loss_avg': 0.023636495799999997,
#   'loss_ref': None,
#   'loss_best': 0.02383807},
#  {'protein_id': '1PUN-7_A',
#   'seq_length_avg': 129.0,
#   'seq_length_ref': 129,
#   'seq_length_best': 129,
#   'rg_avg': 1.4458246330269315,
#   'rg_ref': 1.4647884156322797,
#   'rg_best': 1.4488380393636722,
#   're_avg': 3.693732,
#   're_ref': 3.4276292,
#   're_best': 3.6829488,
#   'helicity_avg': 0.20914728682170544,
#   'helicity_ref': 0.20155038759689922,
#   'helicity_best': 0.17829457364341086,
#   'beta_avg': 0.4240310077519379,
#   'beta_ref': 0.20155038759689922,
#   'beta_best': 0.4418604651162791,
#   'rmsd_avg': 3.8437199652194978,
#   'rmsd_ref': None,
#   'rmsd_best': 3.6144819855690002,
#   'loss_avg': 0.0365829708,
#   'loss_ref': None,
#   'loss_best': 0.03180172},
#  {'protein_id': '1WCW_A',
#   'seq_length_avg': 254.0,
#   'seq_length_ref': 563,
#   'seq_length_best': 254,
#   'rg_avg': 2.008656244754688,
#   'rg_ref': 2.0568565241326526,
#   'rg_best': 1.9967596289414116,
#   're_avg': 1.6561949,
#   're_ref': 1.7278523,
#   're_best': 1.6281358,
#   'helicity_avg': 0.22338582677165356,
#   'helicity_ref': 0.2202486678507993,
#   'helicity_best': 0.25196850393700787,
#   'beta_avg': 0.17976377952755904,
#   'beta_ref': 0.09236234458259325,
#   'beta_best': 0.18503937007874016,
#   'rmsd_avg': 2.89120432138443,
#   'rmsd_ref': None,
#   'rmsd_best': 2.00385645031929,
#   'loss_avg': 0.026785826600000003,
#   'loss_ref': None,
#   'loss_best': 0.02500292},
#  {'protein_id': '1ZFS-13_B',
#   'seq_length_avg': 93.0,
#   'seq_length_ref': 93,
#   'seq_length_best': 93,
#   'rg_avg': 1.405371143204793,
#   'rg_ref': 1.4169490689508006,
#   'rg_best': 1.399024818030358,
#   're_avg': 3.7239523,
#   're_ref': 3.0011091,
#   're_best': 3.7678807,
#   'helicity_avg': 0.6268817204301075,
#   'helicity_ref': 0.6021505376344086,
#   'helicity_best': 0.6021505376344086,
#   'beta_avg': 0.05096774193548388,
#   'beta_ref': 0.043010752688172046,
#   'beta_best': 0.06451612903225806,
#   'rmsd_avg': 2.898601162433624,
#   'rmsd_ref': None,
#   'rmsd_best': 2.632754147052765,
#   'loss_avg': 0.040925833800000005,
#   'loss_ref': None,
#   'loss_best': 0.04091774},
#  {'protein_id': '1VHL_A',
#   'seq_length_avg': 208.0,
#   'seq_length_ref': 472,
#   'seq_length_best': 208,
#   'rg_avg': 1.8959602589664075,
#   'rg_ref': 1.8992859895154297,
#   'rg_best': 1.9003393179127388,
#   're_avg': 1.7909998,
#   're_ref': 2.099823,
#   're_best': 2.0855582,
#   'helicity_avg': 0.5634615384615385,
#   'helicity_ref': 0.25,
#   'helicity_best': 0.5721153846153846,
#   'beta_avg': 0.1326923076923077,
#   'beta_ref': 0.057203389830508475,
#   'beta_best': 0.13942307692307693,
#   'rmsd_avg': 2.068730428814888,
#   'rmsd_ref': None,
#   'rmsd_best': 1.7934750020503998,
#   'loss_avg': 0.023961148600000003,
#   'loss_ref': None,
#   'loss_best': 0.02204516},
#  {'protein_id': '2LKC-4_A',
#   'seq_length_avg': 178.0,
#   'seq_length_ref': 178,
#   'seq_length_best': 178,
#   'rg_avg': 1.564373782876433,
#   'rg_ref': 1.5267790267720203,
#   'rg_best': 1.5666624197111436,
#   're_avg': 1.9107544,
#   're_ref': 3.3938513,
#   're_best': 2.430845,
#   'helicity_avg': 0.248876404494382,
#   'helicity_ref': 0.29213483146067415,
#   'helicity_best': 0.23595505617977527,
#   'beta_avg': 0.22460674157303373,
#   'beta_ref': 0.16292134831460675,
#   'beta_best': 0.21348314606741572,
#   'rmsd_avg': 7.22332239151001,
#   'rmsd_ref': None,
#   'rmsd_best': 6.882128715515137,
#   'loss_avg': 0.04416057440000001,
#   'loss_ref': None,
#   'loss_best': 0.0448415},
#  {'protein_id': '1ZOL_A',
#   'seq_length_avg': 221.0,
#   'seq_length_ref': 479,
#   'seq_length_best': 221,
#   'rg_avg': 1.8346872234432958,
#   'rg_ref': 1.8926576772708048,
#   'rg_best': 1.836652203983538,
#   're_avg': 1.2133946,
#   're_ref': 1.3064977,
#   're_best': 1.1190072,
#   'helicity_avg': 0.5344796380090499,
#   'helicity_ref': 0.23799582463465555,
#   'helicity_best': 0.5429864253393665,
#   'beta_avg': 0.13004524886877827,
#   'beta_ref': 0.05219206680584551,
#   'beta_best': 0.12669683257918551,
#   'rmsd_avg': 2.0532703578472136,
#   'rmsd_ref': None,
#   'rmsd_best': 1.8011504411697388,
#   'loss_avg': 0.0283043892,
#   'loss_ref': None,
#   'loss_best': 0.02771273},
#  {'protein_id': '1NTR-7_A',
#   'seq_length_avg': 124.0,
#   'seq_length_ref': 124,
#   'seq_length_best': 124,
#   'rg_avg': 1.3558081089741691,
#   'rg_ref': 1.3684595127049581,
#   'rg_best': 1.3562722474439692,
#   're_avg': 1.3236502,
#   're_ref': 2.0114977,
#   're_best': 1.441463,
#   'helicity_avg': 0.43629032258064515,
#   'helicity_ref': 0.3225806451612903,
#   'helicity_best': 0.4435483870967742,
#   'beta_avg': 0.18370967741935487,
#   'beta_ref': 0.14516129032258066,
#   'beta_best': 0.1774193548387097,
#   'rmsd_avg': 4.658239954710007,
#   'rmsd_ref': None,
#   'rmsd_best': 4.382267594337463,
#   'loss_avg': 0.038804287,
#   'loss_ref': None,
#   'loss_best': 0.0378371},
#  {'protein_id': '1UR6-4_A',
#   'seq_length_avg': 147.0,
#   'seq_length_ref': 147,
#   'seq_length_best': 147,
#   'rg_avg': 1.5947141437524368,
#   'rg_ref': 1.609904428002966,
#   'rg_best': 1.5958608574188922,
#   're_avg': 3.4879882,
#   're_ref': 3.8295887,
#   're_best': 3.5109327,
#   'helicity_avg': 0.36639455782312935,
#   'helicity_ref': 0.3333333333333333,
#   'helicity_best': 0.3673469387755102,
#   'beta_avg': 0.19782312925170065,
#   'beta_ref': 0.17006802721088435,
#   'beta_best': 0.1836734693877551,
#   'rmsd_avg': 2.4513866156339645,
#   'rmsd_ref': None,
#   'rmsd_best': 2.321580648422241,
#   'loss_avg': 0.020389064000000002,
#   'loss_ref': None,
#   'loss_best': 0.01822528},
#  {'protein_id': '1TNQ-33_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.3081181255575123,
#   'rg_ref': 1.4252344758859228,
#   'rg_best': 1.316852581736776,
#   're_avg': 2.6650019,
#   're_ref': 2.8416898,
#   're_best': 2.415752,
#   'helicity_avg': 0.6391111111111111,
#   'helicity_ref': 0.6111111111111112,
#   'helicity_best': 0.6666666666666666,
#   'beta_avg': 0.06577777777777777,
#   'beta_ref': 0.0,
#   'beta_best': 0.06666666666666667,
#   'rmsd_avg': 5.586712610721588,
#   'rmsd_ref': None,
#   'rmsd_best': 5.239706635475159,
#   'loss_avg': 0.156956243,
#   'loss_ref': None,
#   'loss_best': 0.14814043},
#  {'protein_id': '1S2O_A',
#   'seq_length_avg': 244.0,
#   'seq_length_ref': 593,
#   'seq_length_best': 244,
#   'rg_avg': 1.8563961580875803,
#   'rg_ref': 1.8891333202701512,
#   'rg_best': 1.8690785160124117,
#   're_avg': 1.3200816,
#   're_ref': 1.6644883,
#   're_best': 1.4953043,
#   'helicity_avg': 0.3795901639344262,
#   'helicity_ref': 0.16694772344013492,
#   'helicity_best': 0.3975409836065574,
#   'beta_avg': 0.22475409836065574,
#   'beta_ref': 0.09612141652613827,
#   'beta_best': 0.22131147540983606,
#   'rmsd_avg': 1.9937995374202728,
#   'rmsd_ref': None,
#   'rmsd_best': 1.7509470880031586,
#   'loss_avg': 0.021149085199999997,
#   'loss_ref': None,
#   'loss_best': 0.02270834},
#  {'protein_id': '1JM4-15_B',
#   'seq_length_avg': 118.0,
#   'seq_length_ref': 118,
#   'seq_length_best': 118,
#   'rg_avg': 1.4687882193790696,
#   'rg_ref': 1.4460155096031635,
#   'rg_best': 1.4748113183006428,
#   're_avg': 2.6584516,
#   're_ref': 1.5350693,
#   're_best': 2.3397503,
#   'helicity_avg': 0.6049152542372882,
#   'helicity_ref': 0.5169491525423728,
#   'helicity_best': 0.6016949152542372,
#   'beta_avg': 0.0015254237288135593,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 5.714095556735993,
#   'rmsd_ref': None,
#   'rmsd_best': 4.9582439661026,
#   'loss_avg': 0.033854005,
#   'loss_ref': None,
#   'loss_best': 0.03567515},
#  {'protein_id': '1RRO_A',
#   'seq_length_avg': 108.0,
#   'seq_length_ref': 108,
#   'seq_length_best': 108,
#   'rg_avg': 1.272133752039026,
#   'rg_ref': 1.2724530725126717,
#   'rg_best': 1.2675063092697392,
#   're_avg': 2.4185915,
#   're_ref': 2.343052,
#   're_best': 2.4311023,
#   'helicity_avg': 0.6016666666666667,
#   'helicity_ref': 0.5740740740740741,
#   'helicity_best': 0.5925925925925926,
#   'beta_avg': 0.0374074074074074,
#   'beta_ref': 0.037037037037037035,
#   'beta_best': 0.037037037037037035,
#   'rmsd_avg': 1.7428312808275224,
#   'rmsd_ref': None,
#   'rmsd_best': 1.3163498044013977,
#   'loss_avg': 0.0165376508,
#   'loss_ref': None,
#   'loss_best': 0.01662141},
#  {'protein_id': '2CG6_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.6929694758192233,
#   'rg_ref': 1.8348707549732617,
#   'rg_best': 1.6926476904014995,
#   're_avg': 5.267432,
#   're_ref': 5.884685,
#   're_best': 5.2985206,
#   'helicity_avg': 0.0013333333333333333,
#   'helicity_ref': 0.0,
#   'helicity_best': 0.0,
#   'beta_avg': 0.5391111111111111,
#   'beta_ref': 0.5888888888888889,
#   'beta_best': 0.5,
#   'rmsd_avg': 6.923712837696075,
#   'rmsd_ref': None,
#   'rmsd_best': 6.270231008529663,
#   'loss_avg': 0.1405726776,
#   'loss_ref': None,
#   'loss_best': 0.14362574},
#  {'protein_id': '1MO7-3_A',
#   'seq_length_avg': 213.0,
#   'seq_length_ref': 213,
#   'seq_length_best': 213,
#   'rg_avg': 1.7441566902314036,
#   'rg_ref': 1.7501723738655637,
#   'rg_best': 1.7322656563816048,
#   're_avg': 1.8193933,
#   're_ref': 1.2485683,
#   're_best': 1.7782774,
#   'helicity_avg': 0.05004694835680751,
#   'helicity_ref': 0.2300469483568075,
#   'helicity_best': 0.051643192488262914,
#   'beta_avg': 0.14835680751173708,
#   'beta_ref': 0.13615023474178403,
#   'beta_best': 0.1784037558685446,
#   'rmsd_avg': 17.770196938514708,
#   'rmsd_ref': None,
#   'rmsd_best': 15.430755615234375,
#   'loss_avg': 0.14278839059999998,
#   'loss_ref': None,
#   'loss_best': 0.14652738},
#  {'protein_id': '1VIY_C',
#   'seq_length_avg': 208.0,
#   'seq_length_ref': 361,
#   'seq_length_best': 208,
#   'rg_avg': 1.8834417232324514,
#   'rg_ref': 1.8814879188717157,
#   'rg_best': 1.8864834380318867,
#   're_avg': 1.6155745,
#   're_ref': 2.1756651,
#   're_best': 1.8535644,
#   'helicity_avg': 0.5278846153846153,
#   'helicity_ref': 0.32132963988919666,
#   'helicity_best': 0.5048076923076923,
#   'beta_avg': 0.13480769230769232,
#   'beta_ref': 0.07479224376731301,
#   'beta_best': 0.125,
#   'rmsd_avg': 2.44829683303833,
#   'rmsd_ref': None,
#   'rmsd_best': 1.979939192533493,
#   'loss_avg': 0.0203702796,
#   'loss_ref': None,
#   'loss_best': 0.01855821},
#  {'protein_id': '1RTP_1',
#   'seq_length_avg': 109.0,
#   'seq_length_ref': 109,
#   'seq_length_best': 109,
#   'rg_avg': 1.2641726599302763,
#   'rg_ref': 1.2662036941810717,
#   'rg_best': 1.2604358910368454,
#   're_avg': 2.3861353,
#   're_ref': 2.2933853,
#   're_best': 2.4783542,
#   'helicity_avg': 0.5840366972477063,
#   'helicity_ref': 0.5963302752293578,
#   'helicity_best': 0.5596330275229358,
#   'beta_avg': 0.045871559633027525,
#   'beta_ref': 0.03669724770642202,
#   'beta_best': 0.03669724770642202,
#   'rmsd_avg': 1.4673625707626343,
#   'rmsd_ref': None,
#   'rmsd_best': 1.1347201466560364,
#   'loss_avg': 0.0188676832,
#   'loss_ref': None,
#   'loss_best': 0.01981211},
#  {'protein_id': '1JKN-15_A',
#   'seq_length_avg': 165.0,
#   'seq_length_ref': 165,
#   'seq_length_best': 165,
#   'rg_avg': 1.5403769397813463,
#   'rg_ref': 1.4746645203074344,
#   'rg_best': 1.5422376701774134,
#   're_avg': 3.502859,
#   're_ref': 2.2044623,
#   're_best': 3.0968564,
#   'helicity_avg': 0.07600000000000001,
#   'helicity_ref': 0.23636363636363636,
#   'helicity_best': 0.07878787878787878,
#   'beta_avg': 0.2932121212121212,
#   'beta_ref': 0.2909090909090909,
#   'beta_best': 0.28484848484848485,
#   'rmsd_avg': 4.517032432556152,
#   'rmsd_ref': None,
#   'rmsd_best': 3.792232871055603,
#   'loss_avg': 0.0918019934,
#   'loss_ref': None,
#   'loss_best': 0.08769375},
#  {'protein_id': '1JFJ-3_A',
#   'seq_length_avg': 134.0,
#   'seq_length_ref': 134,
#   'seq_length_best': 134,
#   'rg_avg': 2.283594378507156,
#   'rg_ref': 2.4113610757338453,
#   'rg_best': 2.264461789241235,
#   're_avg': 2.3777323,
#   're_ref': 4.647493,
#   're_best': 2.7145472,
#   'helicity_avg': 0.48776119402985074,
#   'helicity_ref': 0.582089552238806,
#   'helicity_best': 0.4925373134328358,
#   'beta_avg': 0.04029850746268657,
#   'beta_ref': 0.07462686567164178,
#   'beta_best': 0.029850746268656716,
#   'rmsd_avg': 9.19326854944229,
#   'rmsd_ref': None,
#   'rmsd_best': 7.448346018791199,
#   'loss_avg': 0.10164912799999999,
#   'loss_ref': None,
#   'loss_best': 0.10825071},
#  {'protein_id': '1LAH_E',
#   'seq_length_avg': 238.0,
#   'seq_length_ref': 238,
#   'seq_length_best': 238,
#   'rg_avg': 1.7801863080481897,
#   'rg_ref': 1.7698811242291834,
#   'rg_best': 1.7828846376319798,
#   're_avg': 3.3968701,
#   're_ref': 3.2699647,
#   're_best': 3.3540354,
#   'helicity_avg': 0.14621848739495796,
#   'helicity_ref': 0.3739495798319328,
#   'helicity_best': 0.09243697478991597,
#   'beta_avg': 0.24596638655462183,
#   'beta_ref': 0.2184873949579832,
#   'beta_best': 0.25630252100840334,
#   'rmsd_avg': 1.859948143362999,
#   'rmsd_ref': None,
#   'rmsd_best': 1.505015343427658,
#   'loss_avg': 0.022828885400000002,
#   'loss_ref': None,
#   'loss_best': 0.02086102},
#  {'protein_id': '1LIP-2_A',
#   'seq_length_avg': 91.0,
#   'seq_length_ref': 91,
#   'seq_length_best': 91,
#   'rg_avg': 1.1746143182867774,
#   'rg_ref': 1.169525438168934,
#   'rg_best': 1.1717472985809678,
#   're_avg': 1.6908674,
#   're_ref': 1.7588643,
#   're_best': 1.6976975,
#   'helicity_avg': 0.47802197802197804,
#   'helicity_ref': 0.5494505494505495,
#   'helicity_best': 0.5714285714285714,
#   'beta_avg': 0.0006593406593406593,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 1.9900573819875718,
#   'rmsd_ref': None,
#   'rmsd_best': 1.8297210335731506,
#   'loss_avg': 0.0544551634,
#   'loss_ref': None,
#   'loss_best': 0.05646331},
#  {'protein_id': '1AEL-12_A',
#   'seq_length_avg': 131.0,
#   'seq_length_ref': 131,
#   'seq_length_best': 131,
#   'rg_avg': 1.3510840410640141,
#   'rg_ref': 1.3588068325978562,
#   'rg_best': 1.3467389006406194,
#   're_avg': 1.071632,
#   're_ref': 1.3113769,
#   're_best': 1.0997295,
#   'helicity_avg': 0.11267175572519082,
#   'helicity_ref': 0.11450381679389313,
#   'helicity_best': 0.061068702290076333,
#   'beta_avg': 0.6038167938931298,
#   'beta_ref': 0.09923664122137404,
#   'beta_best': 0.6259541984732825,
#   'rmsd_avg': 2.675328069925308,
#   'rmsd_ref': None,
#   'rmsd_best': 2.5261548161506653,
#   'loss_avg': 0.0401934172,
#   'loss_ref': None,
#   'loss_best': 0.03849031},
#  {'protein_id': '2RCS_H',
#   'seq_length_avg': 217.0,
#   'seq_length_ref': 217,
#   'seq_length_best': 217,
#   'rg_avg': 2.281015384188208,
#   'rg_ref': 2.3106167912776807,
#   'rg_best': 2.264274399237055,
#   're_avg': 5.8853645,
#   're_ref': 5.9564,
#   're_best': 5.904182,
#   'helicity_avg': 0.029953917050691246,
#   'helicity_ref': 0.10599078341013825,
#   'helicity_best': 0.027649769585253458,
#   'beta_avg': 0.5388018433179723,
#   'beta_ref': 0.511520737327189,
#   'beta_best': 0.5483870967741935,
#   'rmsd_avg': 5.175159007310867,
#   'rmsd_ref': None,
#   'rmsd_best': 4.119892120361328,
#   'loss_avg': 0.024860816999999997,
#   'loss_ref': None,
#   'loss_best': 0.02390701},
#  {'protein_id': '1JTB-6_A',
#   'seq_length_avg': 91.0,
#   'seq_length_ref': 91,
#   'seq_length_best': 91,
#   'rg_avg': 1.1734733784847964,
#   'rg_ref': 1.1597589113296556,
#   'rg_best': 1.17024806320558,
#   're_avg': 1.6637378,
#   're_ref': 2.2410204,
#   're_best': 1.6615235,
#   'helicity_avg': 0.5487912087912089,
#   'helicity_ref': 0.5274725274725275,
#   'helicity_best': 0.34065934065934067,
#   'beta_avg': 0.0004395604395604396,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 2.667227804660797,
#   'rmsd_ref': None,
#   'rmsd_best': 2.541956603527069,
#   'loss_avg': 0.0314004294,
#   'loss_ref': None,
#   'loss_best': 0.03236562},
#  {'protein_id': '2CG7_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.6785231022097233,
#   'rg_ref': 1.6976704613393547,
#   'rg_best': 1.6855352778627257,
#   're_avg': 5.3483825,
#   're_ref': 5.475552,
#   're_best': 5.386136,
#   'helicity_avg': 0.0006666666666666666,
#   'helicity_ref': 0.0,
#   'helicity_best': 0.0,
#   'beta_avg': 0.5446666666666666,
#   'beta_ref': 0.5888888888888889,
#   'beta_best': 0.5444444444444444,
#   'rmsd_avg': 2.434643065929413,
#   'rmsd_ref': None,
#   'rmsd_best': 1.9583091139793396,
#   'loss_avg': 0.031221022200000004,
#   'loss_ref': None,
#   'loss_best': 0.03054511},
#  {'protein_id': '1SKT-10_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.2372260519031677,
#   'rg_ref': 1.1799446137809735,
#   'rg_best': 1.2386828887723598,
#   're_avg': 2.506346,
#   're_ref': 2.6807613,
#   're_best': 2.468224,
#   'helicity_avg': 0.5195555555555557,
#   'helicity_ref': 0.6444444444444445,
#   'helicity_best': 0.4888888888888889,
#   'beta_avg': 0.057111111111111106,
#   'beta_ref': 0.0,
#   'beta_best': 0.044444444444444446,
#   'rmsd_avg': 3.536953318119049,
#   'rmsd_ref': None,
#   'rmsd_best': 3.191390037536621,
#   'loss_avg': 0.0903598652,
#   'loss_ref': None,
#   'loss_best': 0.09531387},
#  {'protein_id': '1QJ8_A',
#   'seq_length_avg': 148.0,
#   'seq_length_ref': 148,
#   'seq_length_best': 148,
#   'rg_avg': 1.7728431656516637,
#   'rg_ref': 1.8097587546106633,
#   'rg_best': 1.768512278359831,
#   're_avg': 0.7700789,
#   're_ref': 0.8762992,
#   're_best': 0.7501513,
#   'helicity_avg': 0.0012162162162162164,
#   'helicity_ref': 0.0,
#   'helicity_best': 0.0,
#   'beta_avg': 0.7232432432432432,
#   'beta_ref': 0.8175675675675675,
#   'beta_best': 0.7364864864864865,
#   'rmsd_avg': 3.0023277580738066,
#   'rmsd_ref': None,
#   'rmsd_best': 2.713003158569336,
#   'loss_avg': 0.059727049399999996,
#   'loss_ref': None,
#   'loss_best': 0.05645857},
#  {'protein_id': '2K43-1_A',
#   'seq_length_avg': 133.0,
#   'seq_length_ref': 133,
#   'seq_length_best': 133,
#   'rg_avg': 1.3778601017405128,
#   'rg_ref': 1.3829531580246281,
#   'rg_best': 1.376867703670486,
#   're_avg': 1.414293,
#   're_ref': 0.76341385,
#   're_best': 1.4070594,
#   'helicity_avg': 0.0894736842105263,
#   'helicity_ref': 0.06766917293233082,
#   'helicity_best': 0.11278195488721804,
#   'beta_avg': 0.38090225563909774,
#   'beta_ref': 0.42857142857142855,
#   'beta_best': 0.39097744360902253,
#   'rmsd_avg': 2.578453478217125,
#   'rmsd_ref': None,
#   'rmsd_best': 2.480720281600952,
#   'loss_avg': 0.024745030200000004,
#   'loss_ref': None,
#   'loss_best': 0.02479678},
#  {'protein_id': '2JU8-9_A',
#   'seq_length_avg': 127.0,
#   'seq_length_ref': 127,
#   'seq_length_best': 127,
#   'rg_avg': 1.41930415236397,
#   'rg_ref': 1.479947973431861,
#   'rg_best': 1.4304244742110637,
#   're_avg': 1.5379725,
#   're_ref': 1.7028922,
#   're_best': 1.45372,
#   'helicity_avg': 0.12661417322834645,
#   'helicity_ref': 0.10236220472440945,
#   'helicity_best': 0.12598425196850394,
#   'beta_avg': 0.594015748031496,
#   'beta_ref': 0.5748031496062992,
#   'beta_best': 0.6062992125984252,
#   'rmsd_avg': 2.055192247033119,
#   'rmsd_ref': None,
#   'rmsd_best': 1.7853505909442902,
#   'loss_avg': 0.0722030694,
#   'loss_ref': None,
#   'loss_best': 0.05487099},
#  {'protein_id': '1EQM_A',
#   'seq_length_avg': 158.0,
#   'seq_length_ref': 158,
#   'seq_length_best': 158,
#   'rg_avg': 1.5511857792983323,
#   'rg_ref': 1.5820398924197776,
#   'rg_best': 1.5504181162126938,
#   're_avg': 2.8119357,
#   're_ref': 2.9333959,
#   're_best': 2.8373756,
#   'helicity_avg': 0.31569620253164554,
#   'helicity_ref': 0.3037974683544304,
#   'helicity_best': 0.310126582278481,
#   'beta_avg': 0.27379746835443036,
#   'beta_ref': 0.2974683544303797,
#   'beta_best': 0.26582278481012656,
#   'rmsd_avg': 2.9579185783863067,
#   'rmsd_ref': None,
#   'rmsd_best': 2.5764164328575134,
#   'loss_avg': 0.0357041984,
#   'loss_ref': None,
#   'loss_best': 0.03370108},
#  {'protein_id': '1JFK_A',
#   'seq_length_avg': 134.0,
#   'seq_length_ref': 134,
#   'seq_length_best': 134,
#   'rg_avg': 2.1468872207197562,
#   'rg_ref': 1.7344536758887084,
#   'rg_best': 2.109475720747313,
#   're_avg': 2.566733,
#   're_ref': 2.1850386,
#   're_best': 3.0466282,
#   'helicity_avg': 0.5305970149253731,
#   'helicity_ref': 0.5746268656716418,
#   'helicity_best': 0.4626865671641791,
#   'beta_avg': 0.04820895522388059,
#   'beta_ref': 0.08955223880597014,
#   'beta_best': 0.06716417910447761,
#   'rmsd_avg': 11.698485147953033,
#   'rmsd_ref': None,
#   'rmsd_best': 9.36529278755188,
#   'loss_avg': 0.37697684699999995,
#   'loss_ref': None,
#   'loss_best': 0.34421858},
#  {'protein_id': '2NLN-4_A',
#   'seq_length_avg': 108.0,
#   'seq_length_ref': 108,
#   'seq_length_best': 108,
#   'rg_avg': 1.2703265881106762,
#   'rg_ref': 1.2546336290934568,
#   'rg_best': 1.2633884588776114,
#   're_avg': 2.4438686,
#   're_ref': 2.3355737,
#   're_best': 2.4505773,
#   'helicity_avg': 0.5822222222222222,
#   'helicity_ref': 0.5092592592592593,
#   'helicity_best': 0.5648148148148148,
#   'beta_avg': 0.03629629629629629,
#   'beta_ref': 0.037037037037037035,
#   'beta_best': 0.037037037037037035,
#   'rmsd_avg': 3.9768098413944246,
#   'rmsd_ref': None,
#   'rmsd_best': 3.8272133469581604,
#   'loss_avg': 0.0410435516,
#   'loss_ref': None,
#   'loss_best': 0.0423398},
#  {'protein_id': '1WD7_B',
#   'seq_length_avg': 254.0,
#   'seq_length_ref': 482,
#   'seq_length_best': 254,
#   'rg_avg': 2.0012428547923844,
#   'rg_ref': 1.9879112863087185,
#   'rg_best': 1.9552266410072918,
#   're_avg': 1.5647078,
#   're_ref': 1.7519821,
#   're_best': 0.56449366,
#   'helicity_avg': 0.14086614173228346,
#   'helicity_ref': 0.23651452282157676,
#   'helicity_best': 0.11023622047244094,
#   'beta_avg': 0.18102362204724406,
#   'beta_ref': 0.0995850622406639,
#   'beta_best': 0.18110236220472442,
#   'rmsd_avg': 6.490468204021454,
#   'rmsd_ref': None,
#   'rmsd_best': 4.317806363105774,
#   'loss_avg': 0.05435744240000001,
#   'loss_ref': None,
#   'loss_best': 0.05947569},
#  {'protein_id': '1IJA-15_A',
#   'seq_length_avg': 148.0,
#   'seq_length_ref': 148,
#   'seq_length_best': 148,
#   'rg_avg': 1.4965849151187314,
#   'rg_ref': 1.4886379410336839,
#   'rg_best': 1.5025719512159976,
#   're_avg': 2.569763,
#   're_ref': 2.4111195,
#   're_best': 2.4207687,
#   'helicity_avg': 0.09378378378378378,
#   'helicity_ref': 0.02702702702702703,
#   'helicity_best': 0.10135135135135136,
#   'beta_avg': 0.3717567567567568,
#   'beta_ref': 0.34459459459459457,
#   'beta_best': 0.3716216216216216,
#   'rmsd_avg': 4.6379440248012545,
#   'rmsd_ref': None,
#   'rmsd_best': 4.003632068634033,
#   'loss_avg': 0.0324125984,
#   'loss_ref': None,
#   'loss_best': 0.03113128},
#  {'protein_id': '2L51-15_B',
#   'seq_length_avg': 102.0,
#   'seq_length_ref': 102,
#   'seq_length_best': 102,
#   'rg_avg': 1.4973853482407629,
#   'rg_ref': 1.4934972732436027,
#   'rg_best': 1.4939339069320208,
#   're_avg': 4.1904554,
#   're_ref': 2.4190729,
#   're_best': 3.9657025,
#   'helicity_avg': 0.6249019607843137,
#   'helicity_ref': 0.6274509803921569,
#   'helicity_best': 0.6862745098039216,
#   'beta_avg': 0.021568627450980385,
#   'beta_ref': 0.0,
#   'beta_best': 0.0196078431372549,
#   'rmsd_avg': 3.832942098379135,
#   'rmsd_ref': None,
#   'rmsd_best': 3.50466787815094,
#   'loss_avg': 0.030579163200000002,
#   'loss_ref': None,
#   'loss_best': 0.02982929},
#  {'protein_id': '1FMF-4_A',
#   'seq_length_avg': 137.0,
#   'seq_length_ref': 137,
#   'seq_length_best': 137,
#   'rg_avg': 1.3778174941026375,
#   'rg_ref': 1.3657800010787164,
#   'rg_best': 1.3647563858462513,
#   're_avg': 1.3767928,
#   're_ref': 1.8102554,
#   're_best': 1.0364426,
#   'helicity_avg': 0.02233576642335766,
#   'helicity_ref': 0.35036496350364965,
#   'helicity_best': 0.0,
#   'beta_avg': 0.10029197080291972,
#   'beta_ref': 0.22627737226277372,
#   'beta_best': 0.24087591240875914,
#   'rmsd_avg': 16.139618611335756,
#   'rmsd_ref': None,
#   'rmsd_best': 14.412345886230469,
#   'loss_avg': 0.0494204944,
#   'loss_ref': None,
#   'loss_best': 0.05196641},
#  {'protein_id': '2JWW-13_A',
#   'seq_length_avg': 109.0,
#   'seq_length_ref': 109,
#   'seq_length_best': 109,
#   'rg_avg': 1.229555400192997,
#   'rg_ref': 1.2321298729945658,
#   'rg_best': 1.2265939818329503,
#   're_avg': 2.3671906,
#   're_ref': 2.1608996,
#   're_best': 2.2647643,
#   'helicity_avg': 0.5807339449541284,
#   'helicity_ref': 0.6146788990825688,
#   'helicity_best': 0.5688073394495413,
#   'beta_avg': 0.04568807339449542,
#   'beta_ref': 0.01834862385321101,
#   'beta_best': 0.03669724770642202,
#   'rmsd_avg': 2.923494130373001,
#   'rmsd_ref': None,
#   'rmsd_best': 2.759321630001068,
#   'loss_avg': 0.0222461172,
#   'loss_ref': None,
#   'loss_best': 0.0233713},
#  {'protein_id': '2L50-24_A',
#   'seq_length_avg': 102.0,
#   'seq_length_ref': 102,
#   'seq_length_best': 102,
#   'rg_avg': 1.5354759795354689,
#   'rg_ref': 1.5703533189880428,
#   'rg_best': 1.550586775076264,
#   're_avg': 4.300974,
#   're_ref': 4.2333755,
#   're_best': 4.423795,
#   'helicity_avg': 0.6349019607843137,
#   'helicity_ref': 0.6372549019607843,
#   'helicity_best': 0.6372549019607843,
#   'beta_avg': 0.02862745098039216,
#   'beta_ref': 0.0196078431372549,
#   'beta_best': 0.0196078431372549,
#   'rmsd_avg': 3.6626909017562865,
#   'rmsd_ref': None,
#   'rmsd_best': 3.305836319923401,
#   'loss_avg': 0.0404738564,
#   'loss_ref': None,
#   'loss_best': 0.02836835},
#  {'protein_id': '1TJ5_A',
#   'seq_length_avg': 244.0,
#   'seq_length_ref': 514,
#   'seq_length_best': 244,
#   'rg_avg': 1.8012060033266346,
#   'rg_ref': 1.7978188531809627,
#   'rg_best': 1.8059495567816142,
#   're_avg': 1.2658622,
#   're_ref': 1.5359066,
#   're_best': 1.1663724,
#   'helicity_avg': 0.24893442622950823,
#   'helicity_ref': 0.19844357976653695,
#   'helicity_best': 0.3524590163934426,
#   'beta_avg': 0.21934426229508194,
#   'beta_ref': 0.11089494163424124,
#   'beta_best': 0.20081967213114754,
#   'rmsd_avg': 2.3775621473789217,
#   'rmsd_ref': None,
#   'rmsd_best': 2.04091876745224,
#   'loss_avg': 0.0531041422,
#   'loss_ref': None,
#   'loss_best': 0.05308282},
#  {'protein_id': '1URE-8_A',
#   'seq_length_avg': 131.0,
#   'seq_length_ref': 131,
#   'seq_length_best': 131,
#   'rg_avg': 1.3760316884010677,
#   'rg_ref': 1.3823693276881024,
#   'rg_best': 1.372680443438962,
#   're_avg': 1.0955354,
#   're_ref': 1.2458376,
#   're_best': 1.0921106,
#   'helicity_avg': 0.11832061068702289,
#   'helicity_ref': 0.10687022900763359,
#   'helicity_best': 0.1297709923664122,
#   'beta_avg': 0.5984732824427481,
#   'beta_ref': 0.3435114503816794,
#   'beta_best': 0.6030534351145038,
#   'rmsd_avg': 1.7354841887950898,
#   'rmsd_ref': None,
#   'rmsd_best': 1.5945032238960266,
#   'loss_avg': 0.0139386876,
#   'loss_ref': None,
#   'loss_best': 0.01462899},
#  {'protein_id': '1ID8-11_A',
#   'seq_length_avg': 137.0,
#   'seq_length_ref': 137,
#   'seq_length_best': 137,
#   'rg_avg': 1.3956805718882106,
#   'rg_ref': 1.386579453904388,
#   'rg_best': 1.3727260349010546,
#   're_avg': 1.1936948,
#   're_ref': 0.7696255,
#   're_best': 1.2430677,
#   'helicity_avg': 0.02890510948905109,
#   'helicity_ref': 0.34306569343065696,
#   'helicity_best': 0.021897810218978103,
#   'beta_avg': 0.1102189781021898,
#   'beta_ref': 0.18248175182481752,
#   'beta_best': 0.17518248175182483,
#   'rmsd_avg': 16.792570972442626,
#   'rmsd_ref': None,
#   'rmsd_best': 14.838697910308838,
#   'loss_avg': 0.05138319579999999,
#   'loss_ref': None,
#   'loss_best': 0.04661227},
#  {'protein_id': '2ECK_B',
#   'seq_length_avg': 214.0,
#   'seq_length_ref': 214,
#   'seq_length_best': 214,
#   'rg_avg': 1.6975776623892875,
#   'rg_ref': 1.6676586098679578,
#   'rg_best': 1.6757214789811834,
#   're_avg': 1.0232755,
#   're_ref': 1.1106379,
#   're_best': 0.8199292,
#   'helicity_avg': 0.11439252336448597,
#   'helicity_ref': 0.4719626168224299,
#   'helicity_best': 0.12149532710280374,
#   'beta_avg': 0.059065420560747664,
#   'beta_ref': 0.16355140186915887,
#   'beta_best': 0.06542056074766354,
#   'rmsd_avg': 17.486115622520447,
#   'rmsd_ref': None,
#   'rmsd_best': 17.089306116104126,
#   'loss_avg': 0.08612265840000001,
#   'loss_ref': None,
#   'loss_best': 0.08206519},
#  {'protein_id': '4AKE_B',
#   'seq_length_avg': 214.0,
#   'seq_length_ref': 214,
#   'seq_length_best': 214,
#   'rg_avg': 1.810542969978487,
#   'rg_ref': 1.9540572580774156,
#   'rg_best': 1.8119224037165917,
#   're_avg': 1.5054921,
#   're_ref': 1.0526451,
#   're_best': 1.4908051,
#   'helicity_avg': 0.065607476635514,
#   'helicity_ref': 0.5046728971962616,
#   'helicity_best': 0.04672897196261682,
#   'beta_avg': 0.05542056074766354,
#   'beta_ref': 0.1542056074766355,
#   'beta_best': 0.037383177570093455,
#   'rmsd_avg': 18.367933344841003,
#   'rmsd_ref': None,
#   'rmsd_best': 17.74581789970398,
#   'loss_avg': 0.1655304214,
#   'loss_ref': None,
#   'loss_best': 0.15807676},
#  {'protein_id': '1GH1-7_A',
#   'seq_length_avg': 90.0,
#   'seq_length_ref': 90,
#   'seq_length_best': 90,
#   'rg_avg': 1.209082916724698,
#   'rg_ref': 1.2081010680647803,
#   'rg_best': 1.1989061974977309,
#   're_avg': 1.4888691,
#   're_ref': 1.276251,
#   're_best': 1.4591,
#   'helicity_avg': 0.6284444444444444,
#   'helicity_ref': 0.5222222222222223,
#   'helicity_best': 0.6333333333333333,
#   'beta_avg': 0.00022222222222222223,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 2.3111512631177904,
#   'rmsd_ref': None,
#   'rmsd_best': 2.1863874793052673,
#   'loss_avg': 0.0396764134,
#   'loss_ref': None,
#   'loss_best': 0.04251472},
#  {'protein_id': '1AJ7_H',
#   'seq_length_avg': 217.0,
#   'seq_length_ref': 218,
#   'seq_length_best': 217,
#   'rg_avg': 2.1488404699010273,
#   'rg_ref': 2.0855565442834236,
#   'rg_best': 2.142420595921559,
#   're_avg': 5.3562403,
#   're_ref': 4.81921,
#   're_best': 5.291224,
#   'helicity_avg': 0.03133640552995392,
#   'helicity_ref': 0.08256880733944955,
#   'helicity_best': 0.027649769585253458,
#   'beta_avg': 0.5380645161290323,
#   'beta_ref': 0.48623853211009177,
#   'beta_best': 0.5576036866359447,
#   'rmsd_avg': 6.069881814718246,
#   'rmsd_ref': None,
#   'rmsd_best': 4.944274127483368,
#   'loss_avg': 0.094994572,
#   'loss_ref': None,
#   'loss_best': 0.08623003},
#  {'protein_id': '2RS9-13_B',
#   'seq_length_avg': 121.0,
#   'seq_length_ref': 121,
#   'seq_length_best': 121,
#   'rg_avg': 1.562715363690142,
#   'rg_ref': 1.592974442925032,
#   'rg_best': 1.5634893993729524,
#   're_avg': 2.2861478,
#   're_ref': 4.033096,
#   're_best': 2.8129053,
#   'helicity_avg': 0.6231404958677687,
#   'helicity_ref': 0.628099173553719,
#   'helicity_best': 0.6198347107438017,
#   'beta_avg': 0.0,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 3.3605404675006865,
#   'rmsd_ref': None,
#   'rmsd_best': 2.8216856718063354,
#   'loss_avg': 0.033646567200000005,
#   'loss_ref': None,
#   'loss_best': 0.03132673},
#  {'protein_id': '1F3Y-17_A',
#   'seq_length_avg': 165.0,
#   'seq_length_ref': 165,
#   'seq_length_best': 165,
#   'rg_avg': 1.575901315462775,
#   'rg_ref': 1.579156526778092,
#   'rg_best': 1.5706205036638374,
#   're_avg': 3.7764478,
#   're_ref': 2.6920142,
#   're_best': 3.5429466,
#   'helicity_avg': 0.2608484848484849,
#   'helicity_ref': 0.26666666666666666,
#   'helicity_best': 0.2545454545454545,
#   'beta_avg': 0.30727272727272725,
#   'beta_ref': 0.28484848484848485,
#   'beta_best': 0.2727272727272727,
#   'rmsd_avg': 5.886965751647949,
#   'rmsd_ref': None,
#   'rmsd_best': 5.23256242275238,
#   'loss_avg': 0.032446658399999995,
#   'loss_ref': None,
#   'loss_best': 0.03280186},
#  {'protein_id': '1EEJ_B',
#   'seq_length_avg': 216.0,
#   'seq_length_ref': 216,
#   'seq_length_best': 216,
#   'rg_avg': 1.9106455174421435,
#   'rg_ref': 1.9029543846371535,
#   'rg_best': 1.8986015281503952,
#   're_avg': 3.9348288,
#   're_ref': 4.51109,
#   're_best': 3.9884353,
#   'helicity_avg': 0.38842592592592595,
#   'helicity_ref': 0.39814814814814814,
#   'helicity_best': 0.37962962962962965,
#   'beta_avg': 0.2101851851851852,
#   'beta_ref': 0.2175925925925926,
#   'beta_best': 0.2037037037037037,
#   'rmsd_avg': 2.325076997280121,
#   'rmsd_ref': None,
#   'rmsd_best': 1.9017252326011658,
#   'loss_avg': 0.019806742,
#   'loss_ref': None,
#   'loss_best': 0.02025817},
#  {'protein_id': '2UZ5-9_A',
#   'seq_length_avg': 137.0,
#   'seq_length_ref': 137,
#   'seq_length_best': 137,
#   'rg_avg': 1.5048160508279247,
#   'rg_ref': 1.5146809814102677,
#   'rg_best': 1.5049799457084088,
#   're_avg': 5.084501,
#   're_ref': 4.812275,
#   're_best': 4.876509,
#   'helicity_avg': 0.19562043795620437,
#   'helicity_ref': 0.20437956204379562,
#   'helicity_best': 0.2116788321167883,
#   'beta_avg': 0.3162043795620438,
#   'beta_ref': 0.291970802919708,
#   'beta_best': 0.31386861313868614,
#   'rmsd_avg': 2.586214226484299,
#   'rmsd_ref': None,
#   'rmsd_best': 2.464923858642578,
#   'loss_avg': 0.0160523704,
#   'loss_ref': None,
#   'loss_best': 0.01682245},
#  {'protein_id': '1XSC-20_A',
#   'seq_length_avg': 153.0,
#   'seq_length_ref': 153,
#   'seq_length_best': 153,
#   'rg_avg': 1.5090083059221298,
#   'rg_ref': 1.519984173945801,
#   'rg_best': 1.5082835771692298,
#   're_avg': 4.666951,
#   're_ref': 4.5444803,
#   're_best': 4.5833206,
#   'helicity_avg': 0.1552941176470588,
#   'helicity_ref': 0.24836601307189543,
#   'helicity_best': 0.23529411764705882,
#   'beta_avg': 0.3688888888888889,
#   'beta_ref': 0.24836601307189543,
#   'beta_best': 0.37254901960784315,
#   'rmsd_avg': 3.050349462032318,
#   'rmsd_ref': None,
#   'rmsd_best': 2.6565805077552795,
#   'loss_avg': 0.021603058399999996,
#   'loss_ref': None,
#   'loss_best': 0.01816953},
#  {'protein_id': '2LAO_A',
#   'seq_length_avg': 238.0,
#   'seq_length_ref': 238,
#   'seq_length_best': 238,
#   'rg_avg': 1.8676589716269931,
#   'rg_ref': 1.9023473619458546,
#   'rg_best': 1.8655302015214674,
#   're_avg': 3.4547107,
#   're_ref': 3.2307022,
#   're_best': 3.3291187,
#   'helicity_avg': 0.3772268907563025,
#   'helicity_ref': 0.3865546218487395,
#   'helicity_best': 0.36134453781512604,
#   'beta_avg': 0.24924369747899164,
#   'beta_ref': 0.23529411764705882,
#   'beta_best': 0.24789915966386555,
#   'rmsd_avg': 2.5759208679199217,
#   'rmsd_ref': None,
#   'rmsd_best': 2.22633495926857,
#   'loss_avg': 0.0474056032,
#   'loss_ref': None,
#   'loss_best': 0.04671259},
#  {'protein_id': '1EX7_A',
#   'seq_length_avg': 186.0,
#   'seq_length_ref': 397,
#   'seq_length_best': 186,
#   'rg_avg': 1.6734829435924357,
#   'rg_ref': 1.6745988170694863,
#   'rg_best': 1.6772115566125299,
#   're_avg': 1.176392,
#   're_ref': 0.87351733,
#   're_best': 1.2370089,
#   'helicity_avg': 0.4281720430107526,
#   'helicity_ref': 0.20654911838790932,
#   'helicity_best': 0.43010752688172044,
#   'beta_avg': 0.229247311827957,
#   'beta_ref': 0.10327455919395466,
#   'beta_best': 0.23118279569892472,
#   'rmsd_avg': 2.051499906182289,
#   'rmsd_ref': None,
#   'rmsd_best': 1.7790357768535614,
#   'loss_avg': 0.0403321726,
#   'loss_ref': None,
#   'loss_best': 0.03819453},
#  {'protein_id': '2K0G-9_A',
#   'seq_length_avg': 142.0,
#   'seq_length_ref': 142,
#   'seq_length_best': 142,
#   'rg_avg': 1.5104775362242764,
#   'rg_ref': 1.5425134451200722,
#   'rg_best': 1.5104243203080943,
#   're_avg': 5.5243096,
#   're_ref': 5.5740147,
#   're_best': 5.575484,
#   'helicity_avg': 0.3722535211267606,
#   'helicity_ref': 0.36619718309859156,
#   'helicity_best': 0.352112676056338,
#   'beta_avg': 0.2528169014084507,
#   'beta_ref': 0.24647887323943662,
#   'beta_best': 0.24647887323943662,
#   'rmsd_avg': 3.740477979183197,
#   'rmsd_ref': None,
#   'rmsd_best': 3.301647901535034,
#   'loss_avg': 0.033146244799999995,
#   'loss_ref': None,
#   'loss_best': 0.03333196},
#  {'protein_id': '1ORM-9_A',
#   'seq_length_avg': 148.0,
#   'seq_length_ref': 148,
#   'seq_length_best': 148,
#   'rg_avg': 1.7834896343712554,
#   'rg_ref': 1.7943168015194786,
#   'rg_best': 1.785564754044206,
#   're_avg': 0.8047237,
#   're_ref': 1.0817889,
#   're_best': 0.7355452,
#   'helicity_avg': 0.0024324324324324327,
#   'helicity_ref': 0.0,
#   'helicity_best': 0.0,
#   'beta_avg': 0.6944594594594594,
#   'beta_ref': 0.10810810810810811,
#   'beta_best': 0.6891891891891891,
#   'rmsd_avg': 5.249310618638992,
#   'rmsd_ref': None,
#   'rmsd_best': 4.901690781116486,
#   'loss_avg': 0.06291979259999998,
#   'loss_ref': None,
#   'loss_best': 0.06450863},
#  {'protein_id': '2OZW-3_A',
#   'seq_length_avg': 125.0,
#   'seq_length_ref': 125,
#   'seq_length_best': 125,
#   'rg_avg': 1.4471709167671603,
#   'rg_ref': 1.453881292422873,
#   'rg_best': 1.4436716988754246,
#   're_avg': 4.258804,
#   're_ref': 3.6516807,
#   're_best': 4.1848764,
#   'helicity_avg': 0.08416,
#   'helicity_ref': 0.256,
#   'helicity_best': 0.104,
#   'beta_avg': 0.33584,
#   'beta_ref': 0.312,
#   'beta_best': 0.352,
#   'rmsd_avg': 3.6902038931846617,
#   'rmsd_ref': None,
#   'rmsd_best': 3.431198000907898,
#   'loss_avg': 0.0258601116,
#   'loss_ref': None,
#   'loss_best': 0.02669719},
#  {'protein_id': '1O03_A',
#   'seq_length_avg': 221.0,
#   'seq_length_ref': 625,
#   'seq_length_best': 221,
#   'rg_avg': 1.761541801273297,
#   'rg_ref': 1.8091360385974857,
#   'rg_best': 1.7714939256087652,
#   're_avg': 1.2319303,
#   're_ref': 1.5042125,
#   're_best': 1.1689502,
#   'helicity_avg': 0.22615384615384612,
#   'helicity_ref': 0.1696,
#   'helicity_best': 0.24434389140271492,
#   'beta_avg': 0.10895927601809956,
#   'beta_ref': 0.04,
#   'beta_best': 0.13574660633484162,
#   'rmsd_avg': 2.1693048149347307,
#   'rmsd_ref': None,
#   'rmsd_best': 1.8458595871925354,
#   'loss_avg': 0.029010394199999998,
#   'loss_ref': None,
#   'loss_best': 0.03071566},
#  {'protein_id': '2KID-4_A',
#   'seq_length_avg': 148.0,
#   'seq_length_ref': 148,
#   'seq_length_best': 148,
#   'rg_avg': 1.5052372374453022,
#   'rg_ref': 1.5192197788057975,
#   'rg_best': 1.5056057043990647,
#   're_avg': 2.6327767,
#   're_ref': 1.8712226,
#   're_best': 2.4060822,
#   'helicity_avg': 0.085,
#   'helicity_ref': 0.07432432432432433,
#   'helicity_best': 0.06756756756756757,
#   'beta_avg': 0.38445945945945953,
#   'beta_ref': 0.3783783783783784,
#   'beta_best': 0.40540540540540543,
#   'rmsd_avg': 2.6521886348724366,
#   'rmsd_ref': None,
#   'rmsd_best': 2.143739014863968,
#   'loss_avg': 0.014841311800000001,
#   'loss_ref': None,
#   'loss_best': 0.01430358},
#  {'protein_id': '1W4U-9_A',
#   'seq_length_avg': 147.0,
#   'seq_length_ref': 147,
#   'seq_length_best': 147,
#   'rg_avg': 1.5367140993867279,
#   'rg_ref': 1.504562098321368,
#   'rg_best': 1.5300350531726166,
#   're_avg': 3.4432602,
#   're_ref': 3.4691916,
#   're_best': 3.5107443,
#   'helicity_avg': 0.2859863945578231,
#   'helicity_ref': 0.36054421768707484,
#   'helicity_best': 0.3197278911564626,
#   'beta_avg': 0.19918367346938773,
#   'beta_ref': 0.1360544217687075,
#   'beta_best': 0.19047619047619047,
#   'rmsd_avg': 2.3414839535951613,
#   'rmsd_ref': None,
#   'rmsd_best': 2.1543166041374207,
#   'loss_avg': 0.044008945800000004,
#   'loss_ref': None,
#   'loss_best': 0.03798457},
#  {'protein_id': '1XYD-15_B',
#   'seq_length_avg': 92.0,
#   'seq_length_ref': 92,
#   'seq_length_best': 92,
#   'rg_avg': 1.38857811830445,
#   'rg_ref': 1.3892756644904705,
#   'rg_best': 1.381613280349554,
#   're_avg': 3.610201,
#   're_ref': 3.2928271,
#   're_best': 3.6466434,
#   'helicity_avg': 0.6684782608695653,
#   'helicity_ref': 0.5869565217391305,
#   'helicity_best': 0.6847826086956522,
#   'beta_avg': 0.0441304347826087,
#   'beta_ref': 0.021739130434782608,
#   'beta_best': 0.043478260869565216,
#   'rmsd_avg': 3.0117311120033263,
#   'rmsd_ref': None,
#   'rmsd_best': 2.607448101043701,
#   'loss_avg': 0.0264263862,
#   'loss_ref': None,
#   'loss_best': 0.02599281},
#  {'protein_id': '1SYM-2_B',
#   'seq_length_avg': 92.0,
#   'seq_length_ref': 92,
#   'seq_length_best': 92,
#   'rg_avg': 1.4030350885368825,
#   'rg_ref': 1.3988091900471173,
#   'rg_best': 1.4034115585645457,
#   're_avg': 3.5242736,
#   're_ref': 2.2496939,
#   're_best': 3.496343,
#   'helicity_avg': 0.6521739130434783,
#   'helicity_ref': 0.5760869565217391,
#   'helicity_best': 0.6521739130434783,
#   'beta_avg': 0.04434782608695653,
#   'beta_ref': 0.043478260869565216,
#   'beta_best': 0.043478260869565216,
#   'rmsd_avg': 5.055365067720413,
#   'rmsd_ref': None,
#   'rmsd_best': 4.490363299846649,
#   'loss_avg': 0.0285813196,
#   'loss_ref': None,
#   'loss_best': 0.02661981},
#  {'protein_id': '1WUM_A',
#   'seq_length_avg': 118.0,
#   'seq_length_ref': 118,
#   'seq_length_best': 118,
#   'rg_avg': 1.4847793152081967,
#   'rg_ref': 1.4754202455140597,
#   'rg_best': 1.48176398021879,
#   're_avg': 2.8167455,
#   're_ref': 2.7402232,
#   're_best': 2.5888076,
#   'helicity_avg': 0.6079661016949153,
#   'helicity_ref': 0.5508474576271186,
#   'helicity_best': 0.6101694915254238,
#   'beta_avg': 0.00033898305084745765,
#   'beta_ref': 0.0,
#   'beta_best': 0.0,
#   'rmsd_avg': 5.111200517416,
#   'rmsd_ref': None,
#   'rmsd_best': 4.31826114654541,
#   'loss_avg': 0.0281925916,
#   'loss_ref': None,
#   'loss_best': 0.02560373},
#  {'protein_id': '2JU3-3_A',
#   'seq_length_avg': 127.0,
#   'seq_length_ref': 127,
#   'seq_length_best': 127,
#   'rg_avg': 1.4064704531223038,
#   'rg_ref': 1.4255477608115616,
#   'rg_best': 1.4105268725557072,
#   're_avg': 1.5382804,
#   're_ref': 1.6247493,
#   're_best': 1.5605626,
#   'helicity_avg': 0.12330708661417322,
#   'helicity_ref': 0.11023622047244094,
#   'helicity_best': 0.12598425196850394,
#   'beta_avg': 0.6033070866141732,
#   'beta_ref': 0.5905511811023622,
#   'beta_best': 0.6220472440944882,
#   'rmsd_avg': 3.0930724859237673,
#   'rmsd_ref': None,
#   'rmsd_best': 2.7931585907936096,
#   'loss_avg': 0.038599455600000006,
#   'loss_ref': None,
#   'loss_best': 0.03461581},
#  {'protein_id': '1LMZ-9_A',
#   'seq_length_avg': 187.0,
#   'seq_length_ref': 187,
#   'seq_length_best': 187,
#   'rg_avg': 1.7225963141944147,
#   'rg_ref': 1.8024903737328817,
#   'rg_best': 1.7195740354457139,
#   're_avg': 1.2886432,
#   're_ref': 1.9358808,
#   're_best': 1.2643412,
#   'helicity_avg': 0.5554010695187166,
#   'helicity_ref': 0.5508021390374331,
#   'helicity_best': 0.5454545454545454,
#   'beta_avg': 0.030802139037433153,
#   'beta_ref': 0.0213903743315508,
#   'beta_best': 0.03208556149732621,
#   'rmsd_avg': 2.9089747071266174,
#   'rmsd_ref': None,
#   'rmsd_best': 2.7572986483573914,
#   'loss_avg': 0.0559175984,
#   'loss_ref': None,
#   'loss_best': 0.05824946},
#  {'protein_id': '2LKD-18_A',
#   'seq_length_avg': 178.0,
#   'seq_length_ref': 178,
#   'seq_length_best': 178,
#   'rg_avg': 1.5891848890213607,
#   'rg_ref': 1.5728038757539782,
#   'rg_best': 1.5849792513429177,
#   're_avg': 1.7295232,
#   're_ref': 1.4882218,
#   're_best': 1.6602752,
#   'helicity_avg': 0.27752808988764044,
#   'helicity_ref': 0.24719101123595505,
#   'helicity_best': 0.29775280898876405,
#   'beta_avg': 0.22820224719101123,
#   'beta_ref': 0.15168539325842698,
#   'beta_best': 0.23595505617977527,
#   'rmsd_avg': 5.022803831100464,
#   'rmsd_ref': None,
#   'rmsd_best': 4.568021893501282,
#   'loss_avg': 0.0207510408,
#   'loss_ref': None,
#   'loss_best': 0.02184173},
#  {'protein_id': '2CJO-5_A',
#   'seq_length_avg': 97.0,
#   'seq_length_ref': 97,
#   'seq_length_best': 97,
#   'rg_avg': 1.1927868150587164,
#   'rg_ref': 1.1786621032721627,
#   'rg_best': 1.188997032401189,
#   're_avg': 3.5147192,
#   're_ref': 3.5046167,
#   're_best': 3.4941597,
#   'helicity_avg': 0.17793814432989685,
#   'helicity_ref': 0.17525773195876287,
#   'helicity_best': 0.2268041237113402,
#   'beta_avg': 0.30927835051546393,
#   'beta_ref': 0.28865979381443296,
#   'beta_best': 0.29896907216494845,
#   'rmsd_avg': 1.7270753711462021,
#   'rmsd_ref': None,
#   'rmsd_best': 1.474059522151947,
#   'loss_avg': 0.024559029,
#   'loss_ref': None,
#   'loss_best': 0.02169071},
#  {'protein_id': '1MUT-11_A',
#   'seq_length_avg': 129.0,
#   'seq_length_ref': 129,
#   'seq_length_best': 129,
#   'rg_avg': 1.4289443931139385,
#   'rg_ref': 1.4328770580742476,
#   'rg_best': 1.4293267372816754,
#   're_avg': 3.6573346,
#   're_ref': 3.407194,
#   're_best': 3.6066155,
#   'helicity_avg': 0.18387596899224806,
#   'helicity_ref': 0.11627906976744186,
#   'helicity_best': 0.18604651162790697,
#   'beta_avg': 0.42155038759689917,
#   'beta_ref': 0.16279069767441862,
#   'beta_best': 0.43410852713178294,
#   'rmsd_avg': 4.052078425884247,
#   'rmsd_ref': None,
#   'rmsd_best': 3.7496814131736755,
#   'loss_avg': 0.023718256199999996,
#   'loss_ref': None,
#   'loss_best': 0.02238475},
#  {'protein_id': '1KRX-4_A',
#   'seq_length_avg': 124.0,
#   'seq_length_ref': 124,
#   'seq_length_best': 124,
#   'rg_avg': 1.302956047598123,
#   'rg_ref': 1.301471521023024,
#   'rg_best': 1.306542980461353,
#   're_avg': 1.0922568,
#   're_ref': 0.8768204,
#   're_best': 1.0860542,
#   'helicity_avg': 0.2690322580645161,
#   'helicity_ref': 0.4435483870967742,
#   'helicity_best': 0.29838709677419356,
#   'beta_avg': 0.18483870967741936,
#   'beta_ref': 0.14516129032258066,
#   'beta_best': 0.1774193548387097,
#   'rmsd_avg': 3.3039433896541595,
#   'rmsd_ref': None,
#   'rmsd_best': 2.9996395111083984,
#   'loss_avg': 0.0319861146,
#   'loss_ref': None,
#   'loss_best': 0.03319694}]

# %%
df_rows=pd.DataFrame(rows)
df_rows.to_csv('ensemble_average.csv')

# %%
df_rows_rmsd=pd.DataFrame(rows)[['protein_id','rmsd_best','rmsd_avg']]

# %%
df_mean= df_rows_rmsd[['rmsd_best','rmsd_avg']].mean().reset_index()

# %%
df_mean.columns=['Metrics','Value']
df_mean['Metrics']=['Best RMSD','Average RMSD']

# %%
import seaborn as sns

# %%
plt.figure(figsize=(3.75,3.75),dpi=600)
#sns.set_style('whitegrid')
ax = sns.barplot(data=df_mean, x='Metrics',y='Value',hue='Metrics',palette='magma',legend=None)
plt.hlines(4.55,-0.6,1.6,linestyles='--',color='red',label='AlphaSAXS Baseline')
plt.title('Ensemble Method Performance')
plt.ylabel('Accuracy RMSD vs Ground Truth (Å)')
#plt.xlabel('Best vs Average')
plt.ylim(0,5.5)
for containers in ax.containers:
    ax.bar_label(containers, fmt="%.2f Å",padding=3)
plt.tight_layout()
plt.legend(loc=2)
plt.savefig('Ensemble_average.png')

# %%
import pickle

save_data = {
    "rows": rows,
    "results_dict": results_dict,
    "contact_dict": contact_dict,
    "contact_ref": contact_ref
}

with open("protein_analysis.pkl", "wb") as f:
    pickle.dump(save_data, f)

# %%
df_full=pd.DataFrame(rows)

# %%
df_full
# Out:
#    protein_id  seq_length_avg  seq_length_ref  seq_length_best    rg_avg  \
# 0    2K8R-1_A           133.0             133              133  1.373793
# 1   1XSA-23_A           153.0             153              153  1.482322
# 2    1K2H-4_A            93.0              93               93  1.403140
# 3   2D9E-12_A           121.0             121              121  1.526964
# 4   1P7M-18_A           187.0             187              187  1.705712
# ..        ...             ...             ...              ...       ...
# 75   1LMZ-9_A           187.0             187              187  1.722596
# 76  2LKD-18_A           178.0             178              178  1.589185
# 77   2CJO-5_A            97.0              97               97  1.192787
# 78  1MUT-11_A           129.0             129              129  1.428944
# 79   1KRX-4_A           124.0             124              124  1.302956
#
#       rg_ref   rg_best    re_avg    re_ref   re_best  ...  helicity_best  \
# 0   1.377769  1.369565  1.536716  0.862029  1.413769  ...       0.090226
# 1   1.468749  1.487306  4.640028  4.452528  5.152053  ...       0.058824
# 2   1.403545  1.391361  3.809302  3.232320  3.812202  ...       0.580645
# 3   1.518730  1.519589  2.109292  2.177816  1.744408  ...       0.619835
# 4   1.712188  1.702930  1.358845  2.119170  1.425722  ...       0.556150
# ..       ...       ...       ...       ...       ...  ...            ...
# 75  1.802490  1.719574  1.288643  1.935881  1.264341  ...       0.545455
# 76  1.572804  1.584979  1.729523  1.488222  1.660275  ...       0.297753
# 77  1.178662  1.188997  3.514719  3.504617  3.494160  ...       0.226804
# 78  1.432877  1.429327  3.657335  3.407194  3.606616  ...       0.186047
# 79  1.301472  1.306543  1.092257  0.876820  1.086054  ...       0.298387
#
#     beta_avg  beta_ref  beta_best  rmsd_avg  rmsd_ref  rmsd_best  loss_avg  \
# 0   0.396090  0.300752   0.406015  3.713287      None   3.580317  0.015117
# 1   0.342092  0.300654   0.359477  3.553883      None   3.025320  0.029511
# 2   0.045161  0.043011   0.043011  6.449603      None   5.955380  0.070389
# 3   0.000496  0.000000   0.000000  3.445759      None   2.676568  0.019319
# 4   0.028235  0.021390   0.021390  2.406974      None   2.256148  0.015245
# ..       ...       ...        ...       ...       ...        ...       ...
# 75  0.030802  0.021390   0.032086  2.908975      None   2.757299  0.055918
# 76  0.228202  0.151685   0.235955  5.022804      None   4.568022  0.020751
# 77  0.309278  0.288660   0.298969  1.727075      None   1.474060  0.024559
# 78  0.421550  0.162791   0.434109  4.052078      None   3.749681  0.023718
# 79  0.184839  0.145161   0.177419  3.303943      None   2.999640  0.031986
#
#     loss_ref  loss_best
# 0       None   0.013713
# 1       None   0.031879
# 2       None   0.071829
# 3       None   0.019848
# 4       None   0.016372
# ..       ...        ...
# 75      None   0.058249
# 76      None   0.021842
# 77      None   0.021691
# 78      None   0.022385
# 79      None   0.033197
#
# [80 rows x 22 columns]

# %%
'''
with open("protein_analysis.pkl", "rb") as f:
    loaded_data = pickle.load(f)

rows = loaded_data["rows"]
results_dict = loaded_data["results_dict"]
contact_dict = loaded_data["contact_dict"]
contact_ref = loaded_data["contact_ref"]
'''
# Out:
# '\nwith open("protein_analysis.pkl", "rb") as f:\n    loaded_data = pickle.load(f)\n\nrows = loaded_data["rows"]\nresults_dict = loaded_data["results_dict"]\ncontact_dict = loaded_data["contact_dict"]\ncontact_ref = loaded_data["contact_ref"]\n'

# %%
df_result = pd.DataFrame(rows)
print(df_result)
# Out:
#    protein_id  seq_length_avg  seq_length_ref  seq_length_best    rg_avg  \
# 0    2K8R-1_A           133.0             133              133  1.372998
# 1   1XSA-23_A           153.0             153              153  1.477662
# 2    1K2H-4_A            93.0              93               93  1.403884
# 3   2D9E-12_A           121.0             121              121  1.524846
# 4   1P7M-18_A           187.0             187              187  1.707577
# ..        ...             ...             ...              ...       ...
# 75   1LMZ-9_A           187.0             187              187  1.725635
# 76  2LKD-18_A           178.0             178              178  1.589317
# 77   2CJO-5_A            97.0              97               97  1.191392
# 78  1MUT-11_A           129.0             129              129  1.429758
# 79   1KRX-4_A           124.0             124              124  1.303852
#
#       rg_ref   rg_best    re_avg    re_ref   re_best  ...  helicity_best  \
# 0   1.377769  1.369565  1.527013  0.862029  1.413769  ...       0.090226
# 1   1.468749  1.460507  4.548462  4.452528  4.732092  ...       0.156863
# 2   1.403545  1.409652  3.788314  3.232320  3.754080  ...       0.602151
# 3   1.518730  1.521346  2.204446  2.177816  2.004662  ...       0.595041
# 4   1.712188  1.707451  1.324811  2.119170  1.196344  ...       0.545455
# ..       ...       ...       ...       ...       ...  ...            ...
# 75  1.802490  1.727549  1.250790  1.935881  1.309852  ...       0.545455
# 76  1.572804  1.586449  1.683478  1.488222  1.672900  ...       0.235955
# 77  1.178662  1.188997  3.503199  3.504617  3.494160  ...       0.226804
# 78  1.432877  1.429327  3.657240  3.407194  3.606616  ...       0.186047
# 79  1.301472  1.304935  1.085267  0.876820  1.261033  ...       0.403226
#
#     beta_avg  beta_ref  beta_best  rmsd_avg  rmsd_ref  rmsd_best  loss_avg  \
# 0   0.400376  0.300752   0.406015  3.693098      None   3.580317  0.014248
# 1   0.344771  0.300654   0.359477  3.536371      None   3.091354  0.026982
# 2   0.048387  0.043011   0.064516  6.511970      None   6.183617  0.068069
# 3   0.000826  0.000000   0.000000  3.499394      None   2.996730  0.018265
# 4   0.028342  0.021390   0.032086  2.418552      None   2.266626  0.014137
# ..       ...       ...        ...       ...       ...        ...       ...
# 75  0.030481  0.021390   0.032086  2.918787      None   2.816026  0.053461
# 76  0.227247  0.151685   0.235955  5.019865      None   4.734505  0.019762
# 77  0.308247  0.288660   0.298969  1.712470      None   1.474060  0.023343
# 78  0.418992  0.162791   0.434109  4.053123      None   3.749681  0.022563
# 79  0.180242  0.145161   0.177419  3.293179      None   3.104694  0.030335
#
#     loss_ref  loss_best
# 0       None   0.013713
# 1       None   0.028700
# 2       None   0.069146
# 3       None   0.018705
# 4       None   0.013962
# ..       ...        ...
# 75      None   0.052663
# 76      None   0.019970
# 77      None   0.021691
# 78      None   0.022385
# 79      None   0.031670
#
# [80 rows x 22 columns]

# %%
# !pwd
# Out:
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/figures/figure4/full_dataset

# %%
plt.figure(figsize=(5,5))
plt.scatter(df_result['rg_ref'],df_result['rg_avg'], alpha=0.5, color='blue')
plt.plot(np.arange(1,3,0.01),np.arange(1,3,0.01),'--',color='red',alpha=0.3)
plt.xlabel(r'$R_g$ target (nm)',fontsize=15)
plt.ylabel(r'$R_g$ ensemble (nm)',fontsize=15)
plt.savefig('./Rg_ensemble.png', bbox_inches='tight')

# %%
plt.figure(figsize=(5,5))
plt.scatter(df_result['re_ref'],df_result['re_avg'], alpha=0.5, color='blue')
plt.plot(np.arange(1,6,0.01),np.arange(1,6,0.01),'--',color='red',alpha=0.3)
plt.xlabel(r'$R_{ee}$ target (nm)',fontsize=15)
plt.ylabel(r'$R_{ee}$ ensemble (nm)',fontsize=15)
plt.savefig('./figures/Ree_ensemble.png', bbox_inches='tight')

# %% [markdown]
# # Visualize and Save the Result

# %%
ensemble_maps = np.array(contact_maps)
mask_A = labels == 0
mask_B = labels == 1

ensemble_maps_A = ensemble_maps[mask_A] 
ensemble_maps_B = ensemble_maps[mask_B]

average_contact_map_A = np.mean(ensemble_maps_A, axis=0) 
average_contact_map_B = np.mean(ensemble_maps_B, axis=0)
ensemble_maps = np.array(contact_maps)  # shape: (50, N, N)

# Compute average across the first axis (ensemble members)
average_contact_map = np.mean(ensemble_maps, axis=0)

# %%
import shutil
dest_folder_A = os.path.join(output_path,'2RS9_group_A_selected')
dest_folder_B = os.path.join(output_path,'2RS9_group_B_selected')
# Create destination folder if it doesn't exist
os.makedirs(dest_folder_A, exist_ok=True)
os.makedirs(dest_folder_B, exist_ok=True)

# Loop through each file path in the DataFrame and copy
for src in group_A:
    print(src)
    if os.path.isfile(src):  # Check if source file exists
        shutil.copy(src, dest_folder_A)
    else:
        print(f"Missing file: {src}")

print(f"✅ Copied {len(group_A)} files to {dest_folder_A}")

# Loop through each file path in the DataFrame and copy
for src in group_B:
    print(src)
    if os.path.isfile(src):  # Check if source file exists
        shutil.copy(src, dest_folder_B)
    else:
        print(f"Missing file: {src}")
print(f"✅ Copied {len(group_B)} files to {dest_folder_B}")
# Out:
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0307.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0450.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0466.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0321.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0472.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0384.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0473.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0323.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0476.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0347.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0312.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0495.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0413.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0356.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0477.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0404.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0210.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0417.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0310.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0361.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0301.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0444.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0478.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0470.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0141.pdb
# ✅ Copied 25 files to /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9_group_A_selected
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0381.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0403.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0305.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0489.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0464.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0364.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0303.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0467.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0490.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0483.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0484.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0388.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0383.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0406.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0459.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0286.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0337.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0416.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0182.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0385.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0395.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0329.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0479.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0100.pdb
# /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9-13_B/intermediate/2RS9-13_B_iter_0394.pdb
# ✅ Copied 25 files to /global/cfs/cdirs/m4704/100125_Nature_Com_data/ensemble_generated/ensembles/2RS9_group_B_selected

# %%
averages_A,ref_result_A, contact_maps_A,ref_contact_A,results_A, best_A= generate_rmsd_alphaSAXS('2RS9-13_B',ref_path,output_path)

# %%
averages_B,ref_result_B, contact_maps_B,ref_contact_B,results_B, best_B= generate_rmsd_alphaSAXS('2D9E-12_A',ref_path,output_path)

# %%
def flatten_contact_map(cm):
    # Use upper triangle without diagonal
    return cm[np.triu_indices_from(cm, k=1)]
ensemble_data_A = np.array([flatten_contact_map(cm) for cm in contact_maps_A])
reference_vector_A = flatten_contact_map(ref_contact_A)
ensemble_data_A = np.array([flatten_contact_map(cm) for cm in contact_maps_B])
reference_vector_A = flatten_contact_map(ref_contact_B)

# %%
from sklearn.metrics import jaccard_score
jaccard_score_A_A = jaccard_score(ensemble_data_A,reference_vector_A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 from sklearn.metrics import jaccard_score
# ----> 2 jaccard_score_A_A = jaccard_score(ensemble_data_A,reference_vector_A)
#
# NameError: name 'reference_vector_A' is not defined
